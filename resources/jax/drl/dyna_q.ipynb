# %% [markdown]
# Dyna-Q

# %%
import random
import gymnasium as gym
import jax
import jax.numpy as jnp
import optax
import flax.linen as nn

class QNetwork(nn.Module):
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(features=64)(x)
        x = nn.relu(x)
        x = nn.Dense(features=32)(x)
        x = nn.relu(x)
        x = nn.Dense(features=2)(x)
        return x

class DynamicsModel(nn.Module):
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(features=64)(x)
        x = nn.relu(x)
        x = nn.Dense(features=32)(x)
        x = nn.relu(x)
        x = nn.Dense(features=5)(x)
        return x

def epsilon_greedy_policy(q_values, epsilon):
    if random.random() < epsilon:
        return random.randint(0, 1)
    else:
        return int(jnp.argmax(q_values))

def dyna_q(env, q_params, q_opt_state, dynamics_params, dynamics_opt_state, episodes=500, planning_steps=5, epsilon=0.1, gamma=0.99, alpha=0.5):
    rng = jax.random.PRNGKey(0)

    # initialize q network
    q_model = QNetwork()
    q_values = lambda params, s: q_model.apply(params, s.reshape(1, -1))

    # initialize dynamic network
    dynamics_model = DynamicsModel()
    predict_dynamics = lambda params, s, a: dynamics_model.apply(params, jnp.hstack([s, jnp.array([a])]).reshape(1, -1))

    # initialize buffer
    transition_memory = []

    # for each episode
    for episode in range(episodes):
        s, _ = env.reset()
        done = False

        # for each step
        while not done:
            # choose an action a from current state s based on eps-greedy strategy using q values
            a = epsilon_greedy_policy(q_values(q_params, s), epsilon)
            # execute the action and observe the resuting reward and the next state
            s_next, r, done, _, _ = env.step(a)
            # update buffer
            transition_memory.append((s, a, r, s_next))

            # calculate the target q-value for the current state-action pair
            # [0] is batch
            q_s = q_values(q_params, s)
            target = q_s[0].copy()
            if done:
                target = target.at[a].set(r)
            else:
                target = target.at[a].set(r + gamma * jnp.max(q_values(q_params, s_next)))

            # update q-network using temporal difference error, which is the difference between the current estimate of the q-value and the target-q value
            loss_fn = lambda params: jnp.mean((q_model.apply(params, s.reshape(1, -1)) - target) ** 2)
            losses, grad = jax.value_and_grad(loss_fn)(q_params)
            #_, grad = grad_fn(q_params)
            updates, q_opt_state = q_optimizer.update(grad, q_opt_state)
            q_params = optax.apply_updates(q_params, updates)

            # update the dynamic network if the episode is not done
            if not done:
                inputs = jnp.hstack([s, jnp.array([a])])
                target_dynamics = jnp.hstack([r, s_next])
                print(target_dynamics.shape)
                print(dynamics_model.apply(dynamics_params, inputs.reshape(1, -1)))
                loss_fn_dynamics = lambda params: jnp.mean((dynamics_model.apply(params, inputs.reshape(1, -1)) - target_dynamics) ** 2)
                losses_dynamics, grad_dynamics = jax.value_and_grad(loss_fn_dynamics)(dynamics_params)
                #_,grad_dynamics= grad_fn_dynamics(dynamics_params)
                updates, dynamics_opt_state = dynamics_optimizer.update(grad_dynamics, dynamics_opt_state)
                dynamics_params = optax.apply_updates(dynamics_params, updates)

            # perform planning step using the transition memory
            for _ in range(planning_steps):
                # Sample a random transition from memory
                s_sample, a_sample, r_sample, s_next_sample = random.choice(transition_memory)

                # Use the environment model to predict the next state and reward
                r_pred, s_next_pred = predict_dynamics(dynamics_params, s_sample, a_sample).ravel()[0], predict_dynamics(dynamics_params, s_sample, a_sample).ravel()[1:]

                # Calculate the target Q-value for the sampled state-action pair
                q_s_sample = q_values(q_params, s_sample)
                target_sample = q_s_sample[0].copy()

                if s_next_sample is None:
                    target_sample = target_sample.at[a_sample].set(r_pred)
                else:
                    target_sample = target_sample.at[a_sample].set(r_pred + gamma * jnp.max(q_values(q_params, s_next_pred)))

                # Update the Q-value function using the sampled transition
                loss_fn_sample = lambda params: jnp.mean((q_model.apply(params, s_sample.reshape(1, -1)) - target_sample) ** 2)
                _, grad_sample = jax.value_and_grad(loss_fn_sample)(q_params)
                #grad_sample, _ = grad_fn_sample(q_params)
                updates, q_opt_state = q_optimizer.update(grad_sample, q_opt_state)
                q_params = optax.apply_updates(updates, q_params)


            s = s_next
# Out:
# /opt/conda/lib/python3.8/site-packages/flax/core/frozen_dict.py:169: FutureWarning: jax.tree_util.register_keypaths is deprecated, and will be removed in a future release. Please use `register_pytree_with_keys()` instead.
#   jax.tree_util.register_keypaths(

# %%
env = gym.make("CartPole-v1")
rng_q = jax.random.PRNGKey(0)
rng_dynamics = jax.random.PRNGKey(1)

q_model = QNetwork()
q_params = q_model.init(rng_q, jnp.ones((1, 4)))
q_optimizer = optax.adam(1e-4)
q_opt_state = q_optimizer.init(q_params)

dynamics_model = DynamicsModel()
dynamics_params = dynamics_model.init(rng_dynamics, jnp.ones((1, 5)))
dynamics_optimizer = optax.adam(1e-4)
dynamics_opt_state = dynamics_optimizer.init(dynamics_params)

dyna_q(env, q_params, q_opt_state, dynamics_params, dynamics_opt_state)
env.close()
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# (5,)
# [[ 0.00411973 -0.00157021  0.01296842  0.01997603  0.00129607]]
# (5,)
# [[0.04237485 0.03214698 0.04422821 0.02989962 0.07982983]]
# (5,)
# [[0.09223083 0.05695689 0.09872299 0.05783403 0.16825108]]
# (5,)
# [[0.14141014 0.08316255 0.15441047 0.08640867 0.25840452]]
# (5,)
# [[0.19346826 0.10895582 0.21136934 0.11200678 0.35037637]]
# (5,)
# [[0.24827321 0.13466951 0.26957408 0.13468334 0.444739  ]]
# (5,)
# [[0.3054441  0.16079292 0.32884946 0.15498595 0.5421034 ]]
# (5,)
# [[ 0.02422397 -0.00266501  0.00220547  0.00268421  0.0008713 ]]
# (5,)
# [[0.07876007 0.022644   0.04799666 0.03213102 0.07967476]]
# (5,)
# [[ 0.43634105  0.04074448 -0.00952566  0.44173488  0.22512881]]
# (5,)
# [[0.07863867 0.02850013 0.05502581 0.02821335 0.09160579]]
# (5,)
# [[0.13234176 0.04644139 0.11458489 0.05608358 0.19091175]]
# (5,)
# [[0.18750185 0.06887501 0.16938804 0.08336797 0.2855445 ]]
# (5,)
# [[0.24506897 0.09291624 0.22480732 0.10814114 0.3823518 ]]
# (5,)
# [[0.30487266 0.11720402 0.28151172 0.13071866 0.4819183 ]]
# (5,)
# [[0.3669359  0.14189123 0.3393576  0.15142746 0.58486277]]
# (5,)
# [[ 0.02048746 -0.00047016  0.00027031  0.0076034   0.00027947]]
# (5,)
# [[0.07603975 0.01343618 0.03818453 0.03854765 0.07974503]]
# (5,)
# [[0.12995523 0.03023377 0.09143516 0.06788979 0.17312999]]
# (5,)
# [[0.18765622 0.04865807 0.14353625 0.09354874 0.26670685]]
# (5,)
# [[0.24833295 0.06823634 0.19595459 0.11778754 0.3615544 ]]
# (5,)
# [[0.31113076 0.0881056  0.24964859 0.1398103  0.45912883]]
# (5,)
# [[0.37617013 0.10842223 0.3045195  0.15982312 0.5600609 ]]
# (5,)
# [[0.44351277 0.1293185  0.36041912 0.17811556 0.6649704 ]]
# (5,)
# [[ 0.02207082  0.00291064 -0.0091391   0.00841698  0.01011669]]
# (5,)
# [[0.07691695 0.00731303 0.04441452 0.0374795  0.09365399]]
# (5,)
# [[0.13637239 0.02145184 0.09367651 0.06568985 0.18447915]]
# (5,)
# [[0.1974953  0.03601247 0.14293727 0.09157854 0.27610475]]
# (5,)
# [[0.2611202  0.05033597 0.1934087  0.11390696 0.37019795]]
# (5,)
# [[0.3282342  0.06494161 0.24434082 0.13239543 0.46658185]]
# (5,)
# [[0.39715698 0.08003704 0.29671368 0.14886014 0.56687677]]
# (5,)
# [[0.46814263 0.09578577 0.3502265  0.16373605 0.67148244]]
# (5,)
# [[0.5414138  0.11292534 0.40392107 0.17895025 0.78023124]]
# (5,)
# [[ 0.02868348  0.00238204 -0.01189183  0.00975941  0.01313922]]
# (5,)
# [[0.08868775 0.00091551 0.03184723 0.04655943 0.09393845]]
# (5,)
# [[0.1538972  0.01247353 0.07722282 0.07380525 0.18698557]]
# (5,)
# [[0.22051887 0.02434881 0.12258854 0.09948394 0.28118914]]
# (5,)
# [[0.2894984  0.03590587 0.16912267 0.12176724 0.37772545]]
# (5,)
# [[0.36089152 0.04736683 0.21701553 0.1407482  0.47771707]]
# (5,)
# [[0.4337357  0.05942818 0.26645148 0.15813552 0.5819732 ]]
# (5,)
# [[0.50872684 0.07170033 0.31737483 0.17319626 0.6907868 ]]
# (5,)
# [[0.5861856  0.08500536 0.3687308  0.18769719 0.8040699 ]]
# (5,)
# [[ 0.03209639 -0.00325582 -0.00437271 -0.00676956  0.01430089]]
# (5,)
# [[ 0.11703639 -0.0016105   0.03200128  0.01959874  0.10413077]]
# (5,)
# [[0.1855719  0.01007152 0.07944909 0.0499242  0.20985718]]
# (5,)
# [[0.2564509  0.02093467 0.1245739  0.07781548 0.3172073 ]]
# (5,)
# [[0.33031636 0.03225394 0.1695864  0.10390683 0.42665794]]
# (5,)
# [[0.40671724 0.04401288 0.21531035 0.12795123 0.5387391 ]]
# (5,)
# [[0.48565394 0.05615328 0.26194972 0.15003388 0.65433025]]
# (5,)
# [[ 0.01403669 -0.00633667 -0.00849369  0.00115702  0.02506152]]
# (5,)
# [[ 0.08269916 -0.00184278  0.02989513  0.03819005  0.11764215]]
# (5,)
# [[0.15575947 0.00576611 0.06838897 0.0677253  0.2161704 ]]
# (5,)
# [[0.2311397  0.01295445 0.10797346 0.09368791 0.31644338]]
# (5,)
# [[ 0.6071655  -0.04395458  0.02072165  0.47894782  0.43628693]]
# (5,)
# [[0.24540551 0.00783586 0.11167426 0.06631608 0.31596586]]
# (5,)
# [[0.32427642 0.01605145 0.15264103 0.09047333 0.4235429 ]]
# (5,)
# [[0.40540618 0.02345883 0.19395307 0.11207915 0.5345817 ]]
# (5,)
# [[0.48899665 0.03070598 0.23447454 0.13300471 0.6489767 ]]
# (5,)
# [[0.5749572  0.03742339 0.2750153  0.15253283 0.76800334]]
# (5,)
# [[ 0.0261658  -0.00187801 -0.0130352   0.00823359  0.01894583]]
# (5,)
# [[ 0.10563552 -0.01079804  0.01475862  0.04788513  0.11145219]]
# (5,)
# [[ 0.18550429 -0.00480467  0.04935541  0.07606495  0.21231571]]
# (5,)
# [[0.26771316 0.00090025 0.08485214 0.10087534 0.31496927]]
# (5,)
# [[0.35224622 0.00623889 0.12161864 0.12233213 0.41998523]]
# (5,)
# [[0.4389243  0.00987612 0.15791212 0.14128283 0.52852356]]
# (5,)
# [[0.52741593 0.01258947 0.1943139  0.15851985 0.6416753 ]]
# (5,)
# [[0.617688   0.01511574 0.23145375 0.17440942 0.76025134]]
# (5,)
# [[0.7105411  0.01751213 0.26746878 0.1903742  0.88397735]]
# (5,)
# [[ 0.01956162 -0.01331292 -0.01083714  0.00018957  0.05149889]]
# (5,)
# [[ 0.10224228 -0.00647235  0.02736605  0.03107833  0.1561392 ]]
# (5,)
# [[ 0.18334337 -0.00458402  0.06043992  0.06112851  0.26096818]]
# (5,)
# [[ 0.58533317 -0.05374975 -0.07043639  0.4492878   0.3947374 ]]
# (5,)
# [[ 0.19053629 -0.01427054  0.06111431  0.04165533  0.2600153 ]]
# (5,)
# [[ 0.277682   -0.0121326   0.09237551  0.0685626   0.37059072]]
# (5,)
# [[ 0.36816448 -0.01126287  0.12337133  0.09137227  0.48399195]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/diff-buildings/resources/jax/drl/dyna_q.ipynb Cell 3 in <cell line: 15>()
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> dynamics_optimizer = optax.adam(1e-4)
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> dynamics_opt_state = dynamics_optimizer.init(dynamics_params)
# ---> <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> dyna_q(env, q_params, q_opt_state, dynamics_params, dynamics_opt_state)
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> env.close()
#
# /workspaces/diff-buildings/resources/jax/drl/dyna_q.ipynb Cell 3 in dyna_q(env, q_params, q_opt_state, dynamics_params, dynamics_opt_state, episodes, planning_steps, epsilon, gamma, alpha)
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=95'>96</a> r_pred, s_next_pred = predict_dynamics(dynamics_params, s_sample, a_sample).ravel()[0], predict_dynamics(dynamics_params, s_sample, a_sample).ravel()[1:]
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=97'>98</a> # Calculate the target Q-value for the sampled state-action pair
# ---> <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=98'>99</a> q_s_sample = q_values(q_params, s_sample)
#     <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=99'>100</a> target_sample = q_s_sample[0].copy()
#     <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=101'>102</a> if s_next_sample is None:
#
# /workspaces/diff-buildings/resources/jax/drl/dyna_q.ipynb Cell 3 in dyna_q.<locals>.<lambda>(params, s)
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a> # initialize q network
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a> q_model = QNetwork()
# ---> <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a> q_values = lambda params, s: q_model.apply(params, s.reshape(1, -1))
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a> # initialize dynamic network
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a> dynamics_model = DynamicsModel()
#
#     [... skipping hidden 1 frame]
#
# File /opt/conda/lib/python3.8/site-packages/flax/linen/module.py:1467, in Module.apply(self, variables, rngs, method, mutable, capture_intermediates, *args, **kwargs)
#    1465   method = self.__call__
#    1466 method = _get_unbound_fn(method)
# -> 1467 return apply(
#    1468     method, self,
#    1469     mutable=mutable,
#    1470     capture_intermediates=capture_intermediates,
#    1471 )(variables, *args, **kwargs, rngs=rngs)
#
# File /opt/conda/lib/python3.8/site-packages/flax/core/scope.py:933, in apply.<locals>.wrapper(variables, rngs, *args, **kwargs)
#     929   raise errors.ApplyScopeInvalidVariablesStructureError(variables)
#     931 with bind(variables, rngs=rngs, mutable=mutable,
#     932           flags=flags).temporary() as root:
# --> 933   y = fn(root, *args, **kwargs)
#     934 if mutable is not False:
#     935   return y, root.mutable_variables()
#
# File /opt/conda/lib/python3.8/site-packages/flax/linen/module.py:2038, in apply.<locals>.scope_fn(scope, *args, **kwargs)
#    2036 _context.capture_stack.append(capture_intermediates)
#    2037 try:
# -> 2038   return fn(module.clone(parent=scope), *args, **kwargs)
#    2039 finally:
#    2040   _context.capture_stack.pop()
#
# File /opt/conda/lib/python3.8/site-packages/flax/linen/module.py:424, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     422 if args and isinstance(args[0], Module):
#     423   self, args = args[0], args[1:]
# --> 424   return self._call_wrapped_method(fun, args, kwargs)
#     425 else:
#     426   return fun(*args, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/flax/linen/module.py:842, in Module._call_wrapped_method(self, fun, args, kwargs)
#     840 if _use_named_call:
#     841   with jax.named_scope(_derive_profiling_name(self, fun)):
# --> 842     y = fun(self, *args, **kwargs)
#     843 else:
#     844   y = fun(self, *args, **kwargs)
#
# /workspaces/diff-buildings/resources/jax/drl/dyna_q.ipynb Cell 3 in QNetwork.__call__(self, x)
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> x = nn.Dense(features=32)(x)
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> x = nn.relu(x)
# ---> <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a> x = nn.Dense(features=2)(x)
#      <a href='vscode-notebook-cell://dev-container%...-buildings/resources/jax/drl/dyna_q.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> return x
#
# File /opt/conda/lib/python3.8/site-packages/flax/linen/module.py:424, in wrap_method_once.<locals>.wrapped_module_method(*args, **kwargs)
#     422 if args and isinstance(args[0], Module):
#     423   self, args = args[0], args[1:]
# --> 424   return self._call_wrapped_method(fun, args, kwargs)
#     425 else:
#     426   return fun(*args, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/flax/linen/module.py:842, in Module._call_wrapped_method(self, fun, args, kwargs)
#     840 if _use_named_call:
#     841   with jax.named_scope(_derive_profiling_name(self, fun)):
# --> 842     y = fun(self, *args, **kwargs)
#     843 else:
#     844   y = fun(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/flax/linen/linear.py:196, in Dense.__call__(self, inputs)
#     186 @compact
#     187 def __call__(self, inputs: Array) -> Array:
#     188   """Applies a linear transformation to the inputs along the last dimension.
#     189
#     190   Args:
#    (...)
#     194     The transformed input.
#     195   """
# --> 196   kernel = self.param('kernel',
#     197                       self.kernel_init,
#     198                       (jnp.shape(inputs)[-1], self.features),
#     199                       self.param_dtype)
#     200   if self.use_bias:
#     201     bias = self.param('bias', self.bias_init, (self.features,),
#     202                       self.param_dtype)
#
# File /opt/conda/lib/python3.8/site-packages/flax/linen/module.py:1219, in Module.param(self, name, init_fn, unbox, *init_args)
#    1217   raise errors.NameInUseError('param', name, self.__class__.__name__)
#    1218 assert self.scope is not None
# -> 1219 v = self.scope.param(name, init_fn, *init_args, unbox=unbox)
#    1220 self._state.children[name] = 'params'
#    1221 return v
#
# File /opt/conda/lib/python3.8/site-packages/flax/core/scope.py:827, in Scope.param(self, name, init_fn, unbox, *init_args)
#     821 value = self.get_variable('params', name)
#     822 # Validate that the shape of the init_fn output is the same as the shape
#     823 # of the existing parameter. This is to make sure that the hparams set up
#     824 # in a Flax Module match the shapes coming in during apply, and if not,
#     825 # catch it with an error message.
#     826 # NOTE: We could consider moving this to `self.`
# --> 827 abs_value = jax.eval_shape(lambda rng: init_fn(rng, *init_args), abs_rng)
#     828 abs_value_flat = jax.tree_util.tree_leaves(abs_value)
#     829 value_flat = jax.tree_util.tree_leaves(value)
#
#     [... skipping hidden 1 frame]
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/api.py:3348, in eval_shape(fun, *args, **kwargs)
#    3346 wrapped_fun, out_tree = flatten_fun(lu.wrap_init(fun), in_tree)
#    3347 debug_info = pe.debug_info(fun, in_tree, out_tree, True, "eval_shape")
# -> 3348 out = pe.abstract_eval_fun(wrapped_fun.call_wrapped,
#    3349                            *map(shaped_abstractify, args_flat),
#    3350                            debug_info=debug_info)
#    3351 out = [ShapeDtypeStruct(x.shape, x.dtype, x.named_shape) for x in out]
#    3352 return tree_unflatten(out_tree(), out)
#
# File /opt/conda/lib/python3.8/site-packages/jax/interpreters/partial_eval.py:665, in abstract_eval_fun(fun, debug_info, *avals, **params)
#     664 def abstract_eval_fun(fun, *avals, debug_info=None, **params):
# --> 665   _, avals_out, _ = trace_to_jaxpr_dynamic(
#     666       lu.wrap_init(fun, params), avals, debug_info)
#     667   assert all(isinstance(aval, AbstractValue) for aval in avals_out)
#     668   return avals_out
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/profiler.py:314, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     311 @wraps(func)
#     312 def wrapper(*args, **kwargs):
#     313   with TraceAnnotation(name, **decorator_kwargs):
# --> 314     return func(*args, **kwargs)
#     315   return wrapper
#
# File /opt/conda/lib/python3.8/site-packages/jax/interpreters/partial_eval.py:2029, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2027 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:  # type: ignore
#    2028   main.jaxpr_stack = ()  # type: ignore
# -> 2029   jaxpr, out_avals, consts = trace_to_subjaxpr_dynamic(
#    2030     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2031   del main, fun
#    2032 return jaxpr, out_avals, consts
#
# File /opt/conda/lib/python3.8/site-packages/jax/interpreters/partial_eval.py:2046, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2044 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2045 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2046 ans = fun.call_wrapped(*in_tracers_)
#    2047 out_tracers = map(trace.full_raise, ans)
#    2048 jaxpr, consts = frame.to_jaxpr(out_tracers)
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/linear_util.py:165, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     162 gen = gen_static_args = out_store = None
#     164 try:
# --> 165   ans = self.f(*args, **dict(self.params, **kwargs))
#     166 except:
#     167   # Some transformations yield from inside context managers, so we have to
#     168   # interrupt them before reraising the exception. Otherwise they will only
#     169   # get garbage-collected at some later time, running their cleanup tasks
#     170   # only after this exception is handled, which can corrupt the global
#     171   # state.
#     172   while stack:
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/linear_util.py:165, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     162 gen = gen_static_args = out_store = None
#     164 try:
# --> 165   ans = self.f(*args, **dict(self.params, **kwargs))
#     166 except:
#     167   # Some transformations yield from inside context managers, so we have to
#     168   # interrupt them before reraising the exception. Otherwise they will only
#     169   # get garbage-collected at some later time, running their cleanup tasks
#     170   # only after this exception is handled, which can corrupt the global
#     171   # state.
#     172   while stack:
#
# File /opt/conda/lib/python3.8/site-packages/flax/core/scope.py:827, in Scope.param.<locals>.<lambda>(rng)
#     821 value = self.get_variable('params', name)
#     822 # Validate that the shape of the init_fn output is the same as the shape
#     823 # of the existing parameter. This is to make sure that the hparams set up
#     824 # in a Flax Module match the shapes coming in during apply, and if not,
#     825 # catch it with an error message.
#     826 # NOTE: We could consider moving this to `self.`
# --> 827 abs_value = jax.eval_shape(lambda rng: init_fn(rng, *init_args), abs_rng)
#     828 abs_value_flat = jax.tree_util.tree_leaves(abs_value)
#     829 value_flat = jax.tree_util.tree_leaves(value)
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/nn/initializers.py:281, in variance_scaling.<locals>.init(key, shape, dtype)
#     278 if jnp.issubdtype(dtype, jnp.floating):
#     279   # constant is stddev of standard normal truncated to (-2, 2)
#     280   stddev = jnp.sqrt(variance) / jnp.array(.87962566103423978, dtype)
# --> 281   return random.truncated_normal(key, -2, 2, named_shape, dtype) * stddev
#     282 else:
#     283   # constant is stddev of complex standard normal truncated to 2
#     284   stddev = jnp.sqrt(variance) / jnp.array(.95311164380491208, dtype)
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/random.py:688, in truncated_normal(key, lower, upper, shape, dtype)
#     663 def truncated_normal(key: KeyArray,
#     664                      lower: RealArray,
#     665                      upper: RealArray,
#     666                      shape: Optional[Union[Shape, NamedShape]] = None,
#     667                      dtype: DTypeLikeFloat = dtypes.float_) -> Array:
#     668   """Sample truncated standard normal random values with given shape and dtype.
#     669
#     670   Args:
#    (...)
#     686     Returns values in the open interval ``(lower, upper)``.
#     687   """
# --> 688   key, _ = _check_prng_key(key)
#     689   if not dtypes.issubdtype(dtype, np.floating):
#     690     raise ValueError(f"dtype argument to `truncated_normal` must be a float "
#     691                      f"dtype, got {dtype}")
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/random.py:78, in _check_prng_key(key)
#      73   if config.jax_enable_custom_prng:
#      74     warnings.warn(
#      75         'Raw arrays as random keys to jax.random functions are deprecated. '
#      76         'Assuming valid threefry2x32 key for now.',
#      77         FutureWarning)
# ---> 78   return prng.random_wrap(key, impl=default_prng_impl()), True
#      79 else:
#      80   raise TypeError(f'unexpected PRNG key type {type(key)}')
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/prng.py:755, in random_wrap(base_arr, impl)
#     753 def random_wrap(base_arr, *, impl):
#     754   _check_prng_key_data(impl, base_arr)
# --> 755   return random_wrap_p.bind(base_arr, impl=impl)
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/core.py:360, in Primitive.bind(self, *args, **params)
#     357 def bind(self, *args, **params):
#     358   assert (not config.jax_enable_checks or
#     359           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 360   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/core.py:363, in Primitive.bind_with_trace(self, trace, args, params)
#     362 def bind_with_trace(self, trace, args, params):
# --> 363   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     364   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File /opt/conda/lib/python3.8/site-packages/jax/interpreters/partial_eval.py:1781, in DynamicJaxprTrace.process_primitive(self, primitive, tracers, params)
#    1779 if primitive in custom_staging_rules:
#    1780   return custom_staging_rules[primitive](self, *tracers, **params)
# -> 1781 return self.default_process_primitive(primitive, tracers, params)
#
# File /opt/conda/lib/python3.8/site-packages/jax/interpreters/partial_eval.py:1785, in DynamicJaxprTrace.default_process_primitive(self, primitive, tracers, params)
#    1783 def default_process_primitive(self, primitive, tracers, params):
#    1784   avals = [t.aval for t in tracers]
# -> 1785   out_avals, effects = primitive.abstract_eval(*avals, **params)
#    1786   out_avals = [out_avals] if not primitive.multiple_results else out_avals
#    1787   source_info = source_info_util.current()
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/core.py:396, in _effect_free_abstract_eval.<locals>.abstract_eval_(*args, **kwargs)
#     395 def abstract_eval_(*args, **kwargs):
# --> 396   return abstract_eval(*args, **kwargs), no_effects
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/prng.py:763, in random_wrap_abstract_eval(base_arr_aval, impl)
#     760 @random_wrap_p.def_abstract_eval
#     761 def random_wrap_abstract_eval(base_arr_aval, *, impl):
#     762   shape = base_arr_shape_to_keys_shape(impl, base_arr_aval.shape)
# --> 763   return keys_shaped_array(impl, shape)
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/prng.py:273, in keys_shaped_array(impl, shape)
#     272 def keys_shaped_array(impl, shape):
# --> 273   return core.ShapedArray(shape, KeyTy(impl))
#
# File /opt/conda/lib/python3.8/site-packages/jax/_src/core.py:1483, in ShapedArray.__init__(self, shape, dtype, weak_type, named_shape)
#    1482 def __init__(self, shape, dtype, weak_type=False, named_shape=None):
# -> 1483   self.shape = canonicalize_shape(shape)
#    1484   self.dtype = _dtype_object(dtype)
#    1485   self.weak_type = weak_type
#
# KeyboardInterrupt:
