# %%
import jax
import jax.numpy as jnp
import flax.linen as nn
import optax
import gymnasium as gym
import numpy as np
import random

# %%
class QNetwork(nn.Module):
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(64)(x)
        x = nn.relu(x)
        x = nn.Dense(64)(x)
        x = nn.relu(x)
        x = nn.Dense(2)(x)
        return x

class EnvModel(nn.Module):
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(64)(x)
        x = nn.relu(x)
        x = nn.Dense(64)(x)
        x = nn.relu(x)
        x = nn.Dense(5)(x)  # 4 for next state, 1 for reward
        return x

# %%
# Hyperparameters
learning_rate = 1e-3
gamma = 0.99
epsilon = 1.0
epsilon_decay = 0.995
episodes = 500
batch_size = 64
planning_steps = 10

env = gym.make("CartPole-v1",render_mode='rgb_array').env
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

q_network = QNetwork()
env_model = EnvModel()

params = q_network.init(jax.random.PRNGKey(0), jnp.zeros((state_dim,)))
env_model_params = env_model.init(jax.random.PRNGKey(1), jnp.zeros((state_dim + 1,)))

optimizer = optax.adam(learning_rate)
env_model_optimizer = optax.adam(learning_rate)

opt_state = optimizer.init(params)
env_model_opt_state = env_model_optimizer.init(env_model_params)

@jax.jit
def q_learning_update(params, opt_state, state, action, reward, next_state, done):
    def loss_fn(params):
        q_values = q_network.apply(params, state)
        next_q_values = q_network.apply(params, next_state)
        target = reward + gamma * jnp.max(next_q_values, axis=1) * (1 - done)
        loss = jnp.mean((q_values[jnp.arange(q_values.shape[0]), action] - target) ** 2)
        return loss

    loss, grads = jax.value_and_grad(loss_fn)(params)
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    return params, opt_state
 
@jax.jit
def env_model_update(env_model_params, env_model_opt_state, state, action, next_state, reward):
    def env_model_loss_fn(env_model_params):

        state_action = jnp.hstack([state, action.reshape(-1,1)])#, axis=1
        predictions = env_model.apply(env_model_params, state_action)
        target = jnp.concatenate([next_state, reward.reshape(-1,1)], axis=1)
        env_model_loss = jnp.mean(jnp.square(predictions - target))
        return env_model_loss

    env_model_loss, env_model_grads = jax.value_and_grad(env_model_loss_fn)(env_model_params)
    env_model_updates, env_model_opt_state = env_model_optimizer.update(env_model_grads, env_model_opt_state)
    env_model_params = optax.apply_updates(env_model_params, env_model_updates)
    return env_model_params, env_model_opt_state

memory = []
reward_history = []
max_episode_steps = 200
reward_threshold=175 # env.spec.reward_threshold
solved_window = 100

for episode in range(episodes):
    state, _ = env.reset()
    done = False
    total_reward = 0
    step_in_episode = 0

    while not done:
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            q_values = q_network.apply(params, jnp.expand_dims(jnp.array(state), axis=0))
            action = jnp.argmax(q_values).item()

        next_state, reward, done, _, _ = env.step(action)

        memory.append((state, action, reward, next_state, done))
        state = next_state
        total_reward += reward
        step_in_episode += 1

        if len(memory) >= batch_size:
            batch = random.sample(memory, batch_size)

            state_batch = jnp.array([s for (s, _, _, _, _) in batch])
            action_batch = jnp.array([a for (_, a, _, _, _) in batch])
            reward_batch = jnp.array([r for (_, _, r, _, _) in batch])
            next_state_batch = jnp.array([ns for (_, _, _, ns, _) in batch])
            done_batch = jnp.array([d for (_, _, _, _, d) in batch], dtype=jnp.float32)

            params, opt_state = q_learning_update(params, opt_state, state_batch, action_batch, reward_batch, next_state_batch, done_batch)
            env_model_params, env_model_opt_state = env_model_update(env_model_params, env_model_opt_state, state_batch, action_batch, next_state_batch, reward_batch)

            for _ in range(planning_steps):
                planning_batch = random.sample(memory, batch_size)

                state_batch = jnp.array([s for (s, _, _, _, _) in planning_batch])
                action_batch = jnp.array([a for (_, a, _, _, _) in batch])

                state_action_batch = jnp.concatenate([state_batch, action_batch[:, np.newaxis]], axis=1)
                predictions = env_model.apply(env_model_params, state_action_batch)
                next_state_batch, reward_batch = predictions[:, :4], predictions[:, 4]
                done_batch = (jnp.abs(jnp.sum(next_state_batch - state_batch, axis=1)) > 0.5).astype(jnp.float32)

                params, opt_state = q_learning_update(params, opt_state, state_batch, action_batch, reward_batch, next_state_batch, done_batch)
        
        # episode stopping
        # check if the max_episode_steps are met. if so, terminate this episode
        if step_in_episode >= max_episode_steps:
            print(f"Agent reached max_episode_steps in episode {episode}.")
            break

    epsilon = max(epsilon * epsilon_decay, 0.01)
    print(f"Episode {episode + 1}, Total Reward: {total_reward}")

    # outputs
    reward_history.append(total_reward)

    # stop training if average reward reaches requirement
    # Calculate the average reward over the last 'solved_window' episodes
    if episode >= solved_window:
        avg_reward = np.mean(reward_history[-solved_window:])
        print(f'Episode: {episode}, Average Reward: {avg_reward}')

        if avg_reward >= reward_threshold:
            print(f"CartPole-v1 solved in {episode} episodes!")
            break
# Out:
# Episode 1, Total Reward: 12.0
# Episode 2, Total Reward: 10.0
# Episode 3, Total Reward: 11.0
# Episode 4, Total Reward: 11.0
# Episode 5, Total Reward: 31.0
# Episode 6, Total Reward: 20.0
# Episode 7, Total Reward: 23.0
# Episode 8, Total Reward: 15.0
# Episode 9, Total Reward: 56.0
# Episode 10, Total Reward: 9.0
# Episode 11, Total Reward: 15.0
# Episode 12, Total Reward: 28.0
# Episode 13, Total Reward: 11.0
# Episode 14, Total Reward: 15.0
# Episode 15, Total Reward: 17.0
# Episode 16, Total Reward: 23.0
# Episode 17, Total Reward: 24.0
# Episode 18, Total Reward: 18.0
# Episode 19, Total Reward: 21.0
# Episode 20, Total Reward: 51.0
# Episode 21, Total Reward: 9.0
# Episode 22, Total Reward: 47.0
# Episode 23, Total Reward: 24.0
# Episode 24, Total Reward: 23.0
# Episode 25, Total Reward: 13.0
# Episode 26, Total Reward: 18.0
# Episode 27, Total Reward: 16.0
# Episode 28, Total Reward: 41.0
# Episode 29, Total Reward: 27.0
# Episode 30, Total Reward: 16.0
# Episode 31, Total Reward: 11.0
# Episode 32, Total Reward: 24.0
# Episode 33, Total Reward: 26.0
# Episode 34, Total Reward: 32.0
# Episode 35, Total Reward: 15.0
# Episode 36, Total Reward: 14.0
# Episode 37, Total Reward: 21.0
# Episode 38, Total Reward: 55.0
# Episode 39, Total Reward: 33.0
# Episode 40, Total Reward: 14.0
# Episode 41, Total Reward: 40.0
# Episode 42, Total Reward: 13.0
# Episode 43, Total Reward: 16.0
# Episode 44, Total Reward: 21.0
# Episode 45, Total Reward: 48.0
# Episode 46, Total Reward: 20.0
# Episode 47, Total Reward: 16.0
# Episode 48, Total Reward: 20.0
# Episode 49, Total Reward: 29.0
# Episode 50, Total Reward: 12.0
# Episode 51, Total Reward: 9.0
# Episode 52, Total Reward: 31.0
# Episode 53, Total Reward: 42.0
# Episode 54, Total Reward: 30.0
# Episode 55, Total Reward: 30.0
# Episode 56, Total Reward: 29.0
# Episode 57, Total Reward: 83.0
# Episode 58, Total Reward: 64.0
# Episode 59, Total Reward: 26.0
# Episode 60, Total Reward: 17.0
# Episode 61, Total Reward: 21.0
# Episode 62, Total Reward: 36.0
# Episode 63, Total Reward: 23.0
# Episode 64, Total Reward: 41.0
# Episode 65, Total Reward: 70.0
# Episode 66, Total Reward: 20.0
# Episode 67, Total Reward: 51.0
# Episode 68, Total Reward: 24.0
# Episode 69, Total Reward: 27.0
# Episode 70, Total Reward: 36.0
# Episode 71, Total Reward: 13.0
# Episode 72, Total Reward: 21.0
# Episode 73, Total Reward: 75.0
# Episode 74, Total Reward: 62.0
# Episode 75, Total Reward: 13.0
# Episode 76, Total Reward: 36.0
# Episode 77, Total Reward: 27.0
# Episode 78, Total Reward: 26.0
# Episode 79, Total Reward: 129.0
# Episode 80, Total Reward: 30.0
# Episode 81, Total Reward: 75.0
# Episode 82, Total Reward: 92.0
# Episode 83, Total Reward: 35.0
# Episode 84, Total Reward: 91.0
# Episode 85, Total Reward: 90.0
# Episode 86, Total Reward: 19.0
# Episode 87, Total Reward: 15.0
# Episode 88, Total Reward: 37.0
# Episode 89, Total Reward: 91.0
# Episode 90, Total Reward: 56.0
# Episode 91, Total Reward: 42.0
# Episode 92, Total Reward: 48.0
# Episode 93, Total Reward: 61.0
# Episode 94, Total Reward: 55.0
# Episode 95, Total Reward: 73.0
# Episode 96, Total Reward: 26.0
# Episode 97, Total Reward: 75.0
# Episode 98, Total Reward: 77.0
# Episode 99, Total Reward: 43.0
# Episode 100, Total Reward: 30.0
# Episode 101, Total Reward: 46.0
# Episode: 100, Average Reward: 34.42
# Episode 102, Total Reward: 33.0
# Episode: 101, Average Reward: 34.65
# Episode 103, Total Reward: 83.0
# Episode: 102, Average Reward: 35.37
# Episode 104, Total Reward: 94.0
# Episode: 103, Average Reward: 36.2
# Episode 105, Total Reward: 73.0
# Episode: 104, Average Reward: 36.62
# Episode 106, Total Reward: 139.0
# Episode: 105, Average Reward: 37.81
# Episode 107, Total Reward: 37.0
# Episode: 106, Average Reward: 37.95
# Episode 108, Total Reward: 103.0
# Episode: 107, Average Reward: 38.83
# Episode 109, Total Reward: 71.0
# Episode: 108, Average Reward: 38.98
# Episode 110, Total Reward: 25.0
# Episode: 109, Average Reward: 39.14
# Episode 111, Total Reward: 28.0
# Episode: 110, Average Reward: 39.27
# Episode 112, Total Reward: 61.0
# Episode: 111, Average Reward: 39.6
# Episode 113, Total Reward: 65.0
# Episode: 112, Average Reward: 40.14
# Episode 114, Total Reward: 47.0
# Episode: 113, Average Reward: 40.46
# Episode 115, Total Reward: 32.0
# Episode: 114, Average Reward: 40.61
# Episode 116, Total Reward: 72.0
# Episode: 115, Average Reward: 41.1
# Episode 117, Total Reward: 57.0
# Episode: 116, Average Reward: 41.43
# Episode 118, Total Reward: 44.0
# Episode: 117, Average Reward: 41.69
# Episode 119, Total Reward: 17.0
# Episode: 118, Average Reward: 41.65
# Episode 120, Total Reward: 53.0
# Episode: 119, Average Reward: 41.67
# Episode 121, Total Reward: 42.0
# Episode: 120, Average Reward: 42.0
# Episode 122, Total Reward: 15.0
# Episode: 121, Average Reward: 41.68
# Episode 123, Total Reward: 23.0
# Episode: 122, Average Reward: 41.67
# Episode 124, Total Reward: 41.0
# Episode: 123, Average Reward: 41.85
# Episode 125, Total Reward: 32.0
# Episode: 124, Average Reward: 42.04
# Episode 126, Total Reward: 37.0
# Episode: 125, Average Reward: 42.23
# Episode 127, Total Reward: 106.0
# Episode: 126, Average Reward: 43.13
# Episode 128, Total Reward: 49.0
# Episode: 127, Average Reward: 43.21
# Episode 129, Total Reward: 117.0
# Episode: 128, Average Reward: 44.11
# Episode 130, Total Reward: 86.0
# Episode: 129, Average Reward: 44.81
# Episode 131, Total Reward: 110.0
# Episode: 130, Average Reward: 45.8
# Episode 132, Total Reward: 73.0
# Episode: 131, Average Reward: 46.29
# Episode 133, Total Reward: 48.0
# Episode: 132, Average Reward: 46.51
# Episode 134, Total Reward: 33.0
# Episode: 133, Average Reward: 46.52
# Episode 135, Total Reward: 158.0
# Episode: 134, Average Reward: 47.95
# Episode 136, Total Reward: 32.0
# Episode: 135, Average Reward: 48.13
# Episode 137, Total Reward: 43.0
# Episode: 136, Average Reward: 48.35
# Episode 138, Total Reward: 83.0
# Episode: 137, Average Reward: 48.63
# Episode 139, Total Reward: 81.0
# Episode: 138, Average Reward: 49.11
# Episode 140, Total Reward: 67.0
# Episode: 139, Average Reward: 49.64
# Episode 141, Total Reward: 129.0
# Episode: 140, Average Reward: 50.53
# Episode 142, Total Reward: 13.0
# Episode: 141, Average Reward: 50.53
# Episode 143, Total Reward: 101.0
# Episode: 142, Average Reward: 51.38
# Episode 144, Total Reward: 121.0
# Episode: 143, Average Reward: 52.38
# Episode 145, Total Reward: 61.0
# Episode: 144, Average Reward: 52.51
# Episode 146, Total Reward: 31.0
# Episode: 145, Average Reward: 52.62
# Episode 147, Total Reward: 126.0
# Episode: 146, Average Reward: 53.72
# Episode 148, Total Reward: 82.0
# Episode: 147, Average Reward: 54.34
# Episode 149, Total Reward: 104.0
# Episode: 148, Average Reward: 55.09
# Episode 150, Total Reward: 106.0
# Episode: 149, Average Reward: 56.03
# Episode 151, Total Reward: 85.0
# Episode: 150, Average Reward: 56.79
# Episode 152, Total Reward: 58.0
# Episode: 151, Average Reward: 57.06
# Episode 153, Total Reward: 102.0
# Episode: 152, Average Reward: 57.66
# Episode 154, Total Reward: 101.0
# Episode: 153, Average Reward: 58.37
# Episode 155, Total Reward: 182.0
# Episode: 154, Average Reward: 59.89
# Episode 156, Total Reward: 81.0
# Episode: 155, Average Reward: 60.41
# Episode 157, Total Reward: 143.0
# Episode: 156, Average Reward: 61.01
# Episode 158, Total Reward: 34.0
# Episode: 157, Average Reward: 60.71
# Episode 159, Total Reward: 98.0
# Episode: 158, Average Reward: 61.43
# Episode 160, Total Reward: 49.0
# Episode: 159, Average Reward: 61.75
# Episode 161, Total Reward: 124.0
# Episode: 160, Average Reward: 62.78
# Episode 162, Total Reward: 18.0
# Episode: 161, Average Reward: 62.6
# Episode 163, Total Reward: 117.0
# Episode: 162, Average Reward: 63.54
# Episode 164, Total Reward: 97.0
# Episode: 163, Average Reward: 64.1
# Episode 165, Total Reward: 117.0
# Episode: 164, Average Reward: 64.57
# Episode 166, Total Reward: 82.0
# Episode: 165, Average Reward: 65.19
# Episode 167, Total Reward: 44.0
# Episode: 166, Average Reward: 65.12
# Episode 168, Total Reward: 123.0
# Episode: 167, Average Reward: 66.11
# Episode 169, Total Reward: 131.0
# Episode: 168, Average Reward: 67.15
# Episode 170, Total Reward: 148.0
# Episode: 169, Average Reward: 68.27
# Episode 171, Total Reward: 141.0
# Episode: 170, Average Reward: 69.55
# Episode 172, Total Reward: 77.0
# Episode: 171, Average Reward: 70.11
# Episode 173, Total Reward: 123.0
# Episode: 172, Average Reward: 70.59
# Episode 174, Total Reward: 19.0
# Episode: 173, Average Reward: 70.16
# Episode 175, Total Reward: 75.0
# Episode: 174, Average Reward: 70.78
# Episode 176, Total Reward: 45.0
# Episode: 175, Average Reward: 70.87
# Episode 177, Total Reward: 130.0
# Episode: 176, Average Reward: 71.9
# Episode 178, Total Reward: 67.0
# Episode: 177, Average Reward: 72.31
# Agent reached max_episode_steps in episode 178.
# Episode 179, Total Reward: 200.0
# Episode: 178, Average Reward: 73.02
# Episode 180, Total Reward: 24.0
# Episode: 179, Average Reward: 72.96
# Episode 181, Total Reward: 127.0
# Episode: 180, Average Reward: 73.48
# Episode 182, Total Reward: 188.0
# Episode: 181, Average Reward: 74.44
# Episode 183, Total Reward: 28.0
# Episode: 182, Average Reward: 74.37
# Episode 184, Total Reward: 43.0
# Episode: 183, Average Reward: 73.89
# Episode 185, Total Reward: 28.0
# Episode: 184, Average Reward: 73.27
# Episode 186, Total Reward: 25.0
# Episode: 185, Average Reward: 73.33
# Episode 187, Total Reward: 70.0
# Episode: 186, Average Reward: 73.88
# Episode 188, Total Reward: 196.0
# Episode: 187, Average Reward: 75.47
# Episode 189, Total Reward: 153.0
# Episode: 188, Average Reward: 76.09
# Episode 190, Total Reward: 98.0
# Episode: 189, Average Reward: 76.51
# Agent reached max_episode_steps in episode 190.
# Episode 191, Total Reward: 200.0
# Episode: 190, Average Reward: 78.09
# Episode 192, Total Reward: 90.0
# Episode: 191, Average Reward: 78.51
# Agent reached max_episode_steps in episode 192.
# Episode 193, Total Reward: 200.0
# Episode: 192, Average Reward: 79.9
# Episode 194, Total Reward: 134.0
# Episode: 193, Average Reward: 80.69
# Episode 195, Total Reward: 35.0
# Episode: 194, Average Reward: 80.31
# Episode 196, Total Reward: 115.0
# Episode: 195, Average Reward: 81.2
# Episode 197, Total Reward: 160.0
# Episode: 196, Average Reward: 82.05
# Episode 198, Total Reward: 163.0
# Episode: 197, Average Reward: 82.91
# Episode 199, Total Reward: 87.0
# Episode: 198, Average Reward: 83.35
# Agent reached max_episode_steps in episode 199.
# Episode 200, Total Reward: 200.0
# Episode: 199, Average Reward: 85.05
# Episode 201, Total Reward: 52.0
# Episode: 200, Average Reward: 85.11
# Episode 202, Total Reward: 112.0
# Episode: 201, Average Reward: 85.9
# Episode 203, Total Reward: 80.0
# Episode: 202, Average Reward: 85.87
# Episode 204, Total Reward: 60.0
# Episode: 203, Average Reward: 85.53
# Episode 205, Total Reward: 108.0
# Episode: 204, Average Reward: 85.88
# Episode 206, Total Reward: 132.0
# Episode: 205, Average Reward: 85.81
# Episode 207, Total Reward: 121.0
# Episode: 206, Average Reward: 86.65
# Agent reached max_episode_steps in episode 207.
# Episode 208, Total Reward: 200.0
# Episode: 207, Average Reward: 87.62
# Agent reached max_episode_steps in episode 208.
# Episode 209, Total Reward: 200.0
# Episode: 208, Average Reward: 88.91
# Episode 210, Total Reward: 55.0
# Episode: 209, Average Reward: 89.21
# Agent reached max_episode_steps in episode 210.
# Episode 211, Total Reward: 200.0
# Episode: 210, Average Reward: 90.93
# Episode 212, Total Reward: 91.0
# Episode: 211, Average Reward: 91.23
# Episode 213, Total Reward: 191.0
# Episode: 212, Average Reward: 92.49
# Episode 214, Total Reward: 163.0
# Episode: 213, Average Reward: 93.65
# Agent reached max_episode_steps in episode 214.
# Episode 215, Total Reward: 200.0
# Episode: 214, Average Reward: 95.33
# Episode 216, Total Reward: 101.0
# Episode: 215, Average Reward: 95.62
# Episode 217, Total Reward: 178.0
# Episode: 216, Average Reward: 96.83
# Episode 218, Total Reward: 133.0
# Episode: 217, Average Reward: 97.72
# Episode 219, Total Reward: 168.0
# Episode: 218, Average Reward: 99.23
# Episode 220, Total Reward: 150.0
# Episode: 219, Average Reward: 100.2
# Episode 221, Total Reward: 49.0
# Episode: 220, Average Reward: 100.27
# Agent reached max_episode_steps in episode 221.
# Episode 222, Total Reward: 200.0
# Episode: 221, Average Reward: 102.12
# Episode 223, Total Reward: 165.0
# Episode: 222, Average Reward: 103.54
# Episode 224, Total Reward: 109.0
# Episode: 223, Average Reward: 104.22
# Episode 225, Total Reward: 166.0
# Episode: 224, Average Reward: 105.56
# Agent reached max_episode_steps in episode 225.
# Episode 226, Total Reward: 200.0
# Episode: 225, Average Reward: 107.19
# Episode 227, Total Reward: 125.0
# Episode: 226, Average Reward: 107.38
# Agent reached max_episode_steps in episode 227.
# Episode 228, Total Reward: 200.0
# Episode: 227, Average Reward: 108.89
# Episode 229, Total Reward: 38.0
# Episode: 228, Average Reward: 108.1
# Agent reached max_episode_steps in episode 229.
# Episode 230, Total Reward: 200.0
# Episode: 229, Average Reward: 109.24
# Agent reached max_episode_steps in episode 230.
# Episode 231, Total Reward: 200.0
# Episode: 230, Average Reward: 110.14
# Episode 232, Total Reward: 150.0
# Episode: 231, Average Reward: 110.91
# Episode 233, Total Reward: 173.0
# Episode: 232, Average Reward: 112.16
# Episode 234, Total Reward: 41.0
# Episode: 233, Average Reward: 112.24
# Episode 235, Total Reward: 195.0
# Episode: 234, Average Reward: 112.61
# Episode 236, Total Reward: 186.0
# Episode: 235, Average Reward: 114.15
# Episode 237, Total Reward: 155.0
# Episode: 236, Average Reward: 115.27
# Agent reached max_episode_steps in episode 237.
# Episode 238, Total Reward: 200.0
# Episode: 237, Average Reward: 116.44
# Episode 239, Total Reward: 77.0
# Episode: 238, Average Reward: 116.4
# Episode 240, Total Reward: 37.0
# Episode: 239, Average Reward: 116.1
# Agent reached max_episode_steps in episode 240.
# Episode 241, Total Reward: 200.0
# Episode: 240, Average Reward: 116.81
# Episode 242, Total Reward: 159.0
# Episode: 241, Average Reward: 118.27
# Agent reached max_episode_steps in episode 242.
# Episode 243, Total Reward: 200.0
# Episode: 242, Average Reward: 119.26
# Agent reached max_episode_steps in episode 243.
# Episode 244, Total Reward: 200.0
# Episode: 243, Average Reward: 120.05
# Episode 245, Total Reward: 139.0
# Episode: 244, Average Reward: 120.83
# Episode 246, Total Reward: 150.0
# Episode: 245, Average Reward: 122.02
# Episode 247, Total Reward: 82.0
# Episode: 246, Average Reward: 121.58
# Episode 248, Total Reward: 178.0
# Episode: 247, Average Reward: 122.54
# Episode 249, Total Reward: 158.0
# Episode: 248, Average Reward: 123.08
# Episode 250, Total Reward: 177.0
# Episode: 249, Average Reward: 123.79
# Agent reached max_episode_steps in episode 250.
# Episode 251, Total Reward: 200.0
# Episode: 250, Average Reward: 124.94
# Episode 252, Total Reward: 29.0
# Episode: 251, Average Reward: 124.65
# Agent reached max_episode_steps in episode 252.
# Episode 253, Total Reward: 200.0
# Episode: 252, Average Reward: 125.63
# Agent reached max_episode_steps in episode 253.
# Episode 254, Total Reward: 200.0
# Episode: 253, Average Reward: 126.62
# Agent reached max_episode_steps in episode 254.
# Episode 255, Total Reward: 200.0
# Episode: 254, Average Reward: 126.8
# Agent reached max_episode_steps in episode 255.
# Episode 256, Total Reward: 200.0
# Episode: 255, Average Reward: 127.99
# Episode 257, Total Reward: 63.0
# Episode: 256, Average Reward: 127.19
# Episode 258, Total Reward: 26.0
# Episode: 257, Average Reward: 127.11
# Episode 259, Total Reward: 91.0
# Episode: 258, Average Reward: 127.04
# Agent reached max_episode_steps in episode 259.
# Episode 260, Total Reward: 200.0
# Episode: 259, Average Reward: 128.55
# Agent reached max_episode_steps in episode 260.
# Episode 261, Total Reward: 200.0
# Episode: 260, Average Reward: 129.31
# Episode 262, Total Reward: 151.0
# Episode: 261, Average Reward: 130.64
# Agent reached max_episode_steps in episode 262.
# Episode 263, Total Reward: 200.0
# Episode: 262, Average Reward: 131.47
# Agent reached max_episode_steps in episode 263.
# Episode 264, Total Reward: 200.0
# Episode: 263, Average Reward: 132.5
# Episode 265, Total Reward: 99.0
# Episode: 264, Average Reward: 132.32
# Agent reached max_episode_steps in episode 265.
# Episode 266, Total Reward: 200.0
# Episode: 265, Average Reward: 133.5
# Agent reached max_episode_steps in episode 266.
# Episode 267, Total Reward: 200.0
# Episode: 266, Average Reward: 135.06
# Agent reached max_episode_steps in episode 267.
# Episode 268, Total Reward: 200.0
# Episode: 267, Average Reward: 135.83
# Agent reached max_episode_steps in episode 268.
# Episode 269, Total Reward: 200.0
# Episode: 268, Average Reward: 136.52
# Episode 270, Total Reward: 146.0
# Episode: 269, Average Reward: 136.5
# Episode 271, Total Reward: 97.0
# Episode: 270, Average Reward: 136.06
# Agent reached max_episode_steps in episode 271.
# Episode 272, Total Reward: 200.0
# Episode: 271, Average Reward: 137.29
# Agent reached max_episode_steps in episode 272.
# Episode 273, Total Reward: 200.0
# Episode: 272, Average Reward: 138.06
# Agent reached max_episode_steps in episode 273.
# Episode 274, Total Reward: 200.0
# Episode: 273, Average Reward: 139.87
# Episode 275, Total Reward: 97.0
# Episode: 274, Average Reward: 140.09
# Agent reached max_episode_steps in episode 275.
# Episode 276, Total Reward: 200.0
# Episode: 275, Average Reward: 141.64
# Agent reached max_episode_steps in episode 276.
# Episode 277, Total Reward: 200.0
# Episode: 276, Average Reward: 142.34
# Agent reached max_episode_steps in episode 277.
# Episode 278, Total Reward: 200.0
# Episode: 277, Average Reward: 143.67
# Agent reached max_episode_steps in episode 278.
# Episode 279, Total Reward: 200.0
# Episode: 278, Average Reward: 143.67
# Agent reached max_episode_steps in episode 279.
# Episode 280, Total Reward: 200.0
# Episode: 279, Average Reward: 145.43
# Agent reached max_episode_steps in episode 280.
# Episode 281, Total Reward: 200.0
# Episode: 280, Average Reward: 146.16
# Agent reached max_episode_steps in episode 281.
# Episode 282, Total Reward: 200.0
# Episode: 281, Average Reward: 146.28
# Agent reached max_episode_steps in episode 282.
# Episode 283, Total Reward: 200.0
# Episode: 282, Average Reward: 148.0
# Episode 284, Total Reward: 118.0
# Episode: 283, Average Reward: 148.75
# Agent reached max_episode_steps in episode 284.
# Episode 285, Total Reward: 200.0
# Episode: 284, Average Reward: 150.47
# Agent reached max_episode_steps in episode 285.
# Episode 286, Total Reward: 200.0
# Episode: 285, Average Reward: 152.22
# Agent reached max_episode_steps in episode 286.
# Episode 287, Total Reward: 200.0
# Episode: 286, Average Reward: 153.52
# Episode 288, Total Reward: 99.0
# Episode: 287, Average Reward: 152.55
# Episode 289, Total Reward: 193.0
# Episode: 288, Average Reward: 152.95
# Agent reached max_episode_steps in episode 289.
# Episode 290, Total Reward: 200.0
# Episode: 289, Average Reward: 153.97
# Episode 291, Total Reward: 47.0
# Episode: 290, Average Reward: 152.44
# Agent reached max_episode_steps in episode 291.
# Episode 292, Total Reward: 200.0
# Episode: 291, Average Reward: 153.54
# Agent reached max_episode_steps in episode 292.
# Episode 293, Total Reward: 200.0
# Episode: 292, Average Reward: 153.54
# Agent reached max_episode_steps in episode 293.
# Episode 294, Total Reward: 200.0
# Episode: 293, Average Reward: 154.2
# Agent reached max_episode_steps in episode 294.
# Episode 295, Total Reward: 200.0
# Episode: 294, Average Reward: 155.85
# Agent reached max_episode_steps in episode 295.
# Episode 296, Total Reward: 200.0
# Episode: 295, Average Reward: 156.7
# Agent reached max_episode_steps in episode 296.
# Episode 297, Total Reward: 200.0
# Episode: 296, Average Reward: 157.1
# Agent reached max_episode_steps in episode 297.
# Episode 298, Total Reward: 200.0
# Episode: 297, Average Reward: 157.47
# Agent reached max_episode_steps in episode 298.
# Episode 299, Total Reward: 200.0
# Episode: 298, Average Reward: 158.6
# Agent reached max_episode_steps in episode 299.
# Episode 300, Total Reward: 200.0
# Episode: 299, Average Reward: 158.6
# Agent reached max_episode_steps in episode 300.
# Episode 301, Total Reward: 200.0
# Episode: 300, Average Reward: 160.08
# Agent reached max_episode_steps in episode 301.
# Episode 302, Total Reward: 200.0
# Episode: 301, Average Reward: 160.96
# Agent reached max_episode_steps in episode 302.
# Episode 303, Total Reward: 200.0
# Episode: 302, Average Reward: 162.16
# Agent reached max_episode_steps in episode 303.
# Episode 304, Total Reward: 200.0
# Episode: 303, Average Reward: 163.56
# Agent reached max_episode_steps in episode 304.
# Episode 305, Total Reward: 200.0
# Episode: 304, Average Reward: 164.48
# Episode 306, Total Reward: 149.0
# Episode: 305, Average Reward: 164.65
# Episode 307, Total Reward: 166.0
# Episode: 306, Average Reward: 165.1
# Agent reached max_episode_steps in episode 307.
# Episode 308, Total Reward: 200.0
# Episode: 307, Average Reward: 165.1
# Agent reached max_episode_steps in episode 308.
# Episode 309, Total Reward: 200.0
# Episode: 308, Average Reward: 165.1
# Agent reached max_episode_steps in episode 309.
# Episode 310, Total Reward: 200.0
# Episode: 309, Average Reward: 166.55
# Agent reached max_episode_steps in episode 310.
# Episode 311, Total Reward: 200.0
# Episode: 310, Average Reward: 166.55
# Episode 312, Total Reward: 41.0
# Episode: 311, Average Reward: 166.05
# Episode 313, Total Reward: 92.0
# Episode: 312, Average Reward: 165.06
# Agent reached max_episode_steps in episode 313.
# Episode 314, Total Reward: 200.0
# Episode: 313, Average Reward: 165.43
# Agent reached max_episode_steps in episode 314.
# Episode 315, Total Reward: 200.0
# Episode: 314, Average Reward: 165.43
# Agent reached max_episode_steps in episode 315.
# Episode 316, Total Reward: 200.0
# Episode: 315, Average Reward: 166.42
# Episode 317, Total Reward: 67.0
# Episode: 316, Average Reward: 165.31
# Agent reached max_episode_steps in episode 317.
# Episode 318, Total Reward: 200.0
# Episode: 317, Average Reward: 165.98
# Agent reached max_episode_steps in episode 318.
# Episode 319, Total Reward: 200.0
# Episode: 318, Average Reward: 166.3
# Agent reached max_episode_steps in episode 319.
# Episode 320, Total Reward: 200.0
# Episode: 319, Average Reward: 166.8
# Agent reached max_episode_steps in episode 320.
# Episode 321, Total Reward: 200.0
# Episode: 320, Average Reward: 168.31
# Episode 322, Total Reward: 46.0
# Episode: 321, Average Reward: 166.77
# Agent reached max_episode_steps in episode 322.
# Episode 323, Total Reward: 200.0
# Episode: 322, Average Reward: 167.12
# Agent reached max_episode_steps in episode 323.
# Episode 324, Total Reward: 200.0
# Episode: 323, Average Reward: 168.03
# Episode 325, Total Reward: 60.0
# Episode: 324, Average Reward: 166.97
# Agent reached max_episode_steps in episode 325.
# Episode 326, Total Reward: 200.0
# Episode: 325, Average Reward: 166.97
# Agent reached max_episode_steps in episode 326.
# Episode 327, Total Reward: 200.0
# Episode: 326, Average Reward: 167.72
# Agent reached max_episode_steps in episode 327.
# Episode 328, Total Reward: 200.0
# Episode: 327, Average Reward: 167.72
# Agent reached max_episode_steps in episode 328.
# Episode 329, Total Reward: 200.0
# Episode: 328, Average Reward: 169.34
# Agent reached max_episode_steps in episode 329.
# Episode 330, Total Reward: 200.0
# Episode: 329, Average Reward: 169.34
# Agent reached max_episode_steps in episode 330.
# Episode 331, Total Reward: 200.0
# Episode: 330, Average Reward: 169.34
# Agent reached max_episode_steps in episode 331.
# Episode 332, Total Reward: 200.0
# Episode: 331, Average Reward: 169.84
# Agent reached max_episode_steps in episode 332.
# Episode 333, Total Reward: 200.0
# Episode: 332, Average Reward: 170.11
# Episode 334, Total Reward: 57.0
# Episode: 333, Average Reward: 170.27
# Agent reached max_episode_steps in episode 334.
# Episode 335, Total Reward: 200.0
# Episode: 334, Average Reward: 170.32
# Agent reached max_episode_steps in episode 335.
# Episode 336, Total Reward: 200.0
# Episode: 335, Average Reward: 170.46
# Agent reached max_episode_steps in episode 336.
# Episode 337, Total Reward: 200.0
# Episode: 336, Average Reward: 170.91
# Agent reached max_episode_steps in episode 337.
# Episode 338, Total Reward: 200.0
# Episode: 337, Average Reward: 170.91
# Agent reached max_episode_steps in episode 338.
# Episode 339, Total Reward: 200.0
# Episode: 338, Average Reward: 172.14
# Agent reached max_episode_steps in episode 339.
# Episode 340, Total Reward: 200.0
# Episode: 339, Average Reward: 173.77
# Agent reached max_episode_steps in episode 340.
# Episode 341, Total Reward: 200.0
# Episode: 340, Average Reward: 173.77
# Agent reached max_episode_steps in episode 341.
# Episode 342, Total Reward: 200.0
# Episode: 341, Average Reward: 174.18
# Agent reached max_episode_steps in episode 342.
# Episode 343, Total Reward: 200.0
# Episode: 342, Average Reward: 174.18
# Agent reached max_episode_steps in episode 343.
# Episode 344, Total Reward: 200.0
# Episode: 343, Average Reward: 174.18
# Agent reached max_episode_steps in episode 344.
# Episode 345, Total Reward: 200.0
# Episode: 344, Average Reward: 174.79
# Agent reached max_episode_steps in episode 345.
# Episode 346, Total Reward: 200.0
# Episode: 345, Average Reward: 175.29
# CartPole-v1 solved in 345 episodes!

# %%
import matplotlib.pyplot as plt
# Plot the historical rewards
plt.plot(reward_history)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Historical Rewards for CartPole-v1")
plt.show()

# %%
# need a virtual display for rendering in docker
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
from IPython import display as ipythondisplay

# Test the trained agent

print("\nTesting the trained agent...")
env = gym.make("CartPole-v1",render_mode='rgb_array').env
state, _ = env.reset()
state = jnp.array(state, dtype=jnp.float32)

total_reward = 0
done = False
pre_screen = env.render()
step_in_episode = 0

while not done:
    q_values = q_network.apply(params, jnp.expand_dims(jnp.array(state), axis=0))
    action = jnp.argmax(q_values).item()
    #action = agent.act(state)
    next_state, reward, done, _, _ = env.step(action)
    next_state = jnp.array(next_state, dtype=jnp.float32)
    screen = env.render()
    state = next_state
    total_reward += reward
    step_in_episode += 1

    plt.imshow(screen)
    ipythondisplay.clear_output(wait=True)
    ipythondisplay.display(plt.gcf())

    # check if the max_episode_steps are met. if so, terminate this episode
    if step_in_episode >= max_episode_steps:
        print(f"Agent reached max_episode_steps in test.")
        break

    ipythondisplay.clear_output(wait=True)
    
print(f"Total Reward: {total_reward}")

env.close()
# Out:
# Agent reached max_episode_steps in episode 345.
# Total Reward: 200.0

# %%
print(pre_screen)
# Out:
# None
